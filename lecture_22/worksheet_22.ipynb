# %% [markdown]
# # Worksheet 22
#
# Name:  shengwen ouyang
# UID: U01208928
#
# ### Topics
#
# - Neural Networks
#
# ## Neural Networks
#
# Nothing to do in this worksheet except follow along in lecture / use this code to better understand Neural Networks.

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu
import optree

 
#       x[0] --- h1 
#            \ /    \
#             X       output
#            / \    /
#       x[1] --- h2
#
# This is the base model - nothing fancy here

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])
colors = np.hstack([colors] * 20)

# CIRCLE
def generate_circle_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 < 1 or (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 > 1.5, t)))
    Y = np.array([1 if (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 >= 1 else 0 for x in X])
    return X, Y

# LINE
def generate_line_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : x[0] - x[1] < -.5 or x[0] - x[1] > .5, t)))
    Y = np.array([1 if x[0] - x[1] >= 0 else 0 for x in X])
    return X, Y

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# XOR
def generate_xor_data():
    X = np.array([
        [0,0],
        [0,1],
        [1,0],
        [1,1]])
    Y = np.array([x[0]^x[1] for x in X])
    return X, Y

PLOT_HIDDEN_LAYER_2D = False
PLOT_HIDDEN_LAYER_3D = True

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(3, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

# X, Y = generate_circle_data(t)
# X, Y = generate_line_data(t)
# X, Y = generate_curve_data(t)
X, Y = generate_xor_data()

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=1, epochs=1000)

if PLOT_HIDDEN_LAYER_2D:
    # Show the transformation of the input at the first hidden layer
    layer = model.layers[0]
    print(layer.get_config(), layer.get_weights())
    keras_function = keras.backend.function([model.input], [layer.output])
    layerVals = np.array(keras_function(X))[0]
    plt.scatter(layerVals[:,0], layerVals[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
    plt.show()

    # create a mesh to plot in
    h = .02  # step size in the mesh
    x_min, x_max = layerVals[:, 0].min() - .5, layerVals[:, 0].max() + 1
    y_min, y_max = layerVals[:, 1].min() - .5, layerVals[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                        np.arange(y_min, y_max, h))
    meshData = np.c_[xx.ravel(), yy.ravel()]

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh
    fig, ax = plt.subplots()
    layer = model.layers[-1]

    intermediateModel = keras.models.Sequential()
    intermediateModel.add(layers.Dense(1, input_dim=2, activation="sigmoid"))
    intermediateModel.compile(loss="binary_crossentropy")
    intermediateModel.layers[0].set_weights(layer.get_weights())

    Z = intermediateModel.predict(meshData)
    Z = np.array([0 if x < .5 else 1 for x in Z])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)

    T = intermediateModel.predict(layerVals)
    T = np.array([0 if x < .5 else 1 for x in T])
    T = T.reshape(layerVals[:, 0].shape)
    ax.scatter(layerVals[:, 0], layerVals[:, 1], color=colors[T].tolist(), s=100, alpha=.9)
    ax.set_xlabel("h0")
    ax.set_ylabel("h1")
    plt.show()

if PLOT_HIDDEN_LAYER_3D:
    # Show the transformation of the input at the first hidden layer
    layer = model.layers[0]
    print(layer.get_config(), layer.get_weights())
    keras_function = keras.backend.function([model.input], [layer.output])
    layerVals = np.array(keras_function(X))[0]
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(layerVals[:,0], layerVals[:, 1], layerVals[:, 2], color=colors[Y].tolist(), s=100, alpha=.9)
    plt.show()

    # create a mesh to plot in
    h = .1  # step size in the mesh
    x_min, x_max = layerVals[:, 0].min() - .5, layerVals[:, 0].max() + 1
    y_min, y_max = layerVals[:, 1].min() - .5, layerVals[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                        np.arange(y_min, y_max, h))
    meshData = np.c_[xx.ravel(), yy.ravel(), np.zeros(len(xx.ravel()))]

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh
    fig, ax = plt.subplots()
    layer = model.layers[-1]

    intermediateModel = keras.models.Sequential()
    intermediateModel.add(layers.Dense(1, input_dim=3, activation="sigmoid"))
    intermediateModel.compile(loss="binary_crossentropy")
    intermediateModel.layers[0].set_weights(layer.get_weights())

    Z = intermediateModel.predict(meshData)
    Z = np.array([0 if x < .5 else 1 for x in Z])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired) # plot in 2D
    ax.axis('off')

    T = intermediateModel.predict(layerVals)
    T = np.array([0 if x < .5 else 1 for x in T])
    T = T.reshape(layerVals[:, 0].shape)
    ax.scatter(layerVals[:, 0], layerVals[:, 1], color=colors[T].tolist(), s=100, alpha=.9) # plot in 2D
    plt.show()

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
T = model.predict(X)
T = np.array([0 if x < .5 else 1 for x in T])
T = T.reshape(X[:,0].shape)
ax.scatter(X[:, 0], X[:, 1], color=colors[T].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# C:\Users\ouyan\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7251
# Epoch 2/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7235
# Epoch 3/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7228
# Epoch 4/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7223
# Epoch 5/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7218
# Epoch 6/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7214
# Epoch 7/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.7210
# Epoch 8/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7206
# Epoch 9/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.7202
# Epoch 10/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7199
# Epoch 11/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7195
# Epoch 12/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7192
# Epoch 13/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7188
# Epoch 14/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7185
# Epoch 15/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7181
# Epoch 16/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7178
# Epoch 17/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7175
# Epoch 18/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.7171
# Epoch 19/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7168
# Epoch 20/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.7165
# Epoch 21/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.7161
# Epoch 22/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7158
# Epoch 23/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7155
# Epoch 24/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7152
# Epoch 25/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7149
# Epoch 26/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7146
# Epoch 27/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7143
# Epoch 28/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7140
# Epoch 29/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7137
# Epoch 30/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7134
# Epoch 31/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7131
# Epoch 32/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.7128
# Epoch 33/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7125
# Epoch 34/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7122
# Epoch 35/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7119
# Epoch 36/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7117
# Epoch 37/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7114
# Epoch 38/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7111
# Epoch 39/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7108
# Epoch 40/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7106
# Epoch 41/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7103
# Epoch 42/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7100
# Epoch 43/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - loss: 0.7098
# Epoch 44/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7095
# Epoch 45/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7093
# Epoch 46/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.7090
# Epoch 47/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7088
# Epoch 48/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7085
# Epoch 49/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7083
# Epoch 50/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7080
# Epoch 51/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7078
# Epoch 52/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7075
# Epoch 53/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.7073
# Epoch 54/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7071
# Epoch 55/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7068
# Epoch 56/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7066
# Epoch 57/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7064
# Epoch 58/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7061
# Epoch 59/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7059
# Epoch 60/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7057
# Epoch 61/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7055
# Epoch 62/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7052
# Epoch 63/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7050
# Epoch 64/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7048
# Epoch 65/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7046
# Epoch 66/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7044
# Epoch 67/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7042
# Epoch 68/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7040
# Epoch 69/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7038
# Epoch 70/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7036
# Epoch 71/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7034
# Epoch 72/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7032
# Epoch 73/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7030
# Epoch 74/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7028
# Epoch 75/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7026
# Epoch 76/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7024
# Epoch 77/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.7022
# Epoch 78/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7020
# Epoch 79/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7018
# Epoch 80/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7017
# Epoch 81/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7015
# Epoch 82/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7013
# Epoch 83/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7011
# Epoch 84/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7009
# Epoch 85/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7008
# Epoch 86/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7006
# Epoch 87/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7004
# Epoch 88/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7002
# Epoch 89/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7001
# Epoch 90/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6999
# Epoch 91/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6997
# Epoch 92/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6996
# Epoch 93/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6994
# Epoch 94/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6993
# Epoch 95/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6991
# Epoch 96/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6989
# Epoch 97/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6988
# Epoch 98/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6986
# Epoch 99/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6985
# Epoch 100/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6983
# Epoch 101/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6982
# Epoch 102/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6980
# Epoch 103/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6979
# Epoch 104/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6977
# Epoch 105/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6976
# Epoch 106/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6974
# Epoch 107/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6973
# Epoch 108/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6972
# Epoch 109/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6970
# Epoch 110/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6969
# Epoch 111/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6967
# Epoch 112/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6966
# Epoch 113/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6965
# Epoch 114/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6963
# Epoch 115/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6962
# Epoch 116/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6961
# Epoch 117/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6959
# Epoch 118/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6958
# Epoch 119/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6957
# Epoch 120/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6956
# Epoch 121/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6954
# Epoch 122/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6953
# Epoch 123/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6952
# Epoch 124/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6951
# Epoch 125/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6949
# Epoch 126/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6948
# Epoch 127/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6947
# Epoch 128/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6946
# Epoch 129/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6945
# Epoch 130/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6944
# Epoch 131/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6942
# Epoch 132/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6941
# Epoch 133/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6940
# Epoch 134/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6939
# Epoch 135/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6938
# Epoch 136/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6937
# Epoch 137/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6936
# Epoch 138/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6935
# Epoch 139/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6934
# Epoch 140/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6933
# Epoch 141/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6932
# Epoch 142/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6931
# Epoch 143/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6930
# Epoch 144/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6929
# Epoch 145/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6928
# Epoch 146/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6927
# Epoch 147/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6926
# Epoch 148/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6925
# Epoch 149/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6924
# Epoch 150/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6923
# Epoch 151/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6922
# Epoch 152/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6921
# Epoch 153/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6920
# Epoch 154/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6919
# Epoch 155/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6918
# Epoch 156/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6917
# Epoch 157/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6916
# Epoch 158/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6915
# Epoch 159/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6915
# Epoch 160/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6914
# Epoch 161/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6913
# Epoch 162/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6912
# Epoch 163/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6911
# Epoch 164/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6910
# Epoch 165/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6909
# Epoch 166/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6909
# Epoch 167/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6908
# Epoch 168/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6907
# Epoch 169/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6906
# Epoch 170/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6905
# Epoch 171/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6905
# Epoch 172/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6904
# Epoch 173/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6903
# Epoch 174/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6902
# Epoch 175/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6902
# Epoch 176/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6901
# Epoch 177/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6900
# Epoch 178/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6899
# Epoch 179/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6899
# Epoch 180/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6898
# Epoch 181/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6897
# Epoch 182/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6897
# Epoch 183/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6896
# Epoch 184/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6895
# Epoch 185/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6894
# Epoch 186/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 0.6894
# Epoch 187/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6893
# Epoch 188/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6892
# Epoch 189/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6892
# Epoch 190/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6891
# Epoch 191/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6890
# Epoch 192/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6890
# Epoch 193/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6889
# Epoch 194/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6888
# Epoch 195/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6888
# Epoch 196/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6887
# Epoch 197/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6887
# Epoch 198/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6886
# Epoch 199/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6885
# Epoch 200/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6885
# Epoch 201/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6884
# Epoch 202/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6884
# Epoch 203/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6883
# Epoch 204/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6882
# Epoch 205/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6882
# Epoch 206/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6881
# Epoch 207/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6881
# Epoch 208/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6880
# Epoch 209/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6880
# Epoch 210/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6879
# Epoch 211/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6879
# Epoch 212/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6878
# Epoch 213/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6877
# Epoch 214/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6877
# Epoch 215/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6876
# Epoch 216/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6876
# Epoch 217/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6875
# Epoch 218/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6875
# Epoch 219/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6874
# Epoch 220/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6874
# Epoch 221/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6873
# Epoch 222/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6873
# Epoch 223/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6872
# Epoch 224/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6872
# Epoch 225/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6871
# Epoch 226/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6871
# Epoch 227/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6871
# Epoch 228/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6870
# Epoch 229/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6870
# Epoch 230/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6869
# Epoch 231/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6869
# Epoch 232/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6868
# Epoch 233/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6868
# Epoch 234/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6867
# Epoch 235/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6867
# Epoch 236/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6867
# Epoch 237/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6866
# Epoch 238/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6866
# Epoch 239/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6865
# Epoch 240/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6865
# Epoch 241/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6864
# Epoch 242/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6864
# Epoch 243/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6864
# Epoch 244/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6863
# Epoch 245/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6863
# Epoch 246/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6862
# Epoch 247/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6862
# Epoch 248/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6862
# Epoch 249/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6861
# Epoch 250/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6861
# Epoch 251/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6860
# Epoch 252/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6860
# Epoch 253/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6860
# Epoch 254/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6859
# Epoch 255/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6859
# Epoch 256/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6859
# Epoch 257/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6858
# Epoch 258/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6858
# Epoch 259/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6858
# Epoch 260/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6857
# Epoch 261/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6857
# Epoch 262/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6857
# Epoch 263/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6856
# Epoch 264/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6856
# Epoch 265/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6856
# Epoch 266/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6855
# Epoch 267/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6855
# Epoch 268/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6855
# Epoch 269/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6854
# Epoch 270/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6854
# Epoch 271/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6854
# Epoch 272/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6853
# Epoch 273/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6853
# Epoch 274/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6853
# Epoch 275/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6852
# Epoch 276/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6852
# Epoch 277/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6852
# Epoch 278/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6852
# Epoch 279/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6851
# Epoch 280/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6851
# Epoch 281/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6851
# Epoch 282/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.
1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6825
# Epoch 701/1000
# ...
# Epoch 784/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 785/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6827
# Epoch 786/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 787/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 788/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 789/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 790/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 791/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 792/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6827
# Epoch 793/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 794/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 795/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 796/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 797/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 798/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 799/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6827
# Epoch 800/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 801/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 802/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 803/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 804/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 805/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 806/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 807/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 808/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 809/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 810/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 811/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 812/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 813/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 814/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 815/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 816/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 817/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 818/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 819/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 820/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 821/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 822/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6827
# Epoch 823/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 824/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 825/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 826/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 827/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 828/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 829/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 830/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6827
# Epoch 831/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 832/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6828
# Epoch 833/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 834/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 835/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 836/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 837/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 838/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 839/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 840/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 841/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 842/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 843/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 844/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 845/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 846/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6828
# Epoch 847/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 848/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 849/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 850/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 851/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6828
# Epoch 852/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 853/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 854/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 855/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 856/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 857/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 858/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6828
# Epoch 859/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 860/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 861/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 862/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6828
# Epoch 863/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 864/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 865/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 866/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 867/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 868/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 869/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6828
# Epoch 870/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6828
# Epoch 871/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 872/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6828
# Epoch 873/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6828
# Epoch 874/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 875/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 876/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 877/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 878/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 879/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 880/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6828
# Epoch 881/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 882/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 883/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6828
# Epoch 884/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 885/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 886/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 887/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 888/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 889/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6828
# Epoch 890/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6828
# Epoch 891/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6828
# Epoch 892/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 893/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 894/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 895/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 896/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 897/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 898/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 899/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 900/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 901/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 902/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 903/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 904/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 905/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 906/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 907/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 908/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 909/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6829
# Epoch 910/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 911/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 912/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6829
# Epoch 913/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 914/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6829
# Epoch 915/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 916/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 917/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 918/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 919/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 920/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 921/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6829
# Epoch 922/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 923/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 924/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 925/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 926/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 927/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 928/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 929/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 930/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6829
# Epoch 931/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 932/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 933/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6829
# Epoch 934/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 935/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 936/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 937/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6829
# Epoch 938/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 939/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 940/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 941/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 942/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 943/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 944/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 945/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 946/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 947/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 948/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 949/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 950/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 951/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6829
# Epoch 952/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 953/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 954/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 955/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6829
# Epoch 956/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 957/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 958/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6829
# Epoch 959/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 960/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 961/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6829
# Epoch 962/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 963/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 964/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 965/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 966/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 967/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 968/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 969/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 970/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 971/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 972/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 973/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.6830
# Epoch 974/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 975/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 976/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 977/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 978/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 979/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 980/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 981/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 982/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 983/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 984/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 985/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 986/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6830
# Epoch 987/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 988/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 989/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 990/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 991/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 992/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 993/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 994/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 995/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 996/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 997/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 998/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 999/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# Epoch 1000/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6830
# {'name': 'dense_2', 'trainable': True, 'dtype': 'float32', 'units': 3, 'activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None} [array([[-0.40882453,  1.0412714 , -0.60078025],
#        [ 0.4901771 , -0.7431329 ,  0.49076682]], dtype=float32), array([-0.20137565,  0.427986  , -0.24600975], dtype=float32)]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <cell line: 122>()
#     124 layer = model.layers[0]
#     125 print(layer.get_config(), layer.get_weights())
# --> 126 keras_function = keras.backend.function([model.input], [layer.output])
#     127 layerVals = np.array(keras_function(X))[0]
#     128 fig = plt.figure()
#
# AttributeError: module 'keras._tf_keras.keras.backend' has no attribute 'function'
